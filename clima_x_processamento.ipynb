# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
FULL_PATH = 'C:\\Users\\caval\\Documents\\tech-challenge-01'

# %%
data = pd.read_csv(f'{FULL_PATH}\\content\\dados-clima.csv')

# %%
data.head()
# Out:
#   Data Medicao  NUMERO DE DIAS COM PRECIP. PLUV, MENSAL (AUT)(n̼mero)  \
# 0   2008-01-31                                                8.0
# 1   2008-02-29                                                9.0
# 2   2008-03-31                                               13.0
# 3   2008-04-30                                               12.0
# 4   2008-05-31                                               10.0
#
#   PRECIPITACAO TOTAL, MENSAL (AUT)(mm)  \
# 0                                  119
# 1                                 86,6
# 2                                 72,4
# 3                                114,2
# 4                                   75
#
#   PRESSAO ATMOSFERICA, MEDIA MENSAL (AUT)(mB)  \
# 0                                  962,534005
# 1                                  962,577557
# 2                                  963,780803
# 3                                  963,796111
# 4                                  967,464275
#
# ...

# %%
display(data.index)
# Out:
# RangeIndex(start=0, stop=7236, step=1)

# %%
data = data.set_index('Data Medicao')
data.index
# Out:
# Index(['2008-01-31', '2008-02-29', '2008-03-31', '2008-04-30', '2008-05-31',
#        '2008-06-30', '2008-07-31', '2008-08-31', '2008-09-30', '2008-10-31',
#        ...
#        '2022-08-31', '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31',
#        '2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30', '2023-05-31'],
#       dtype='object', name='Data Medicao', length=7236)

# %%
data.index = data.index.str[:4]
data.index
# Out:
# Index(['2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008',
#        '2008',
#        ...
#        '2022', '2022', '2022', '2022', '2022', '2023', '2023', '2023', '2023',
#        '2023'],
#       dtype='object', name='Data Medicao', length=7236)

# %%
data = data.drop(['Unnamed: 7'], axis=1)

# %%
data.head(12)
# Out:
#               NUMERO DE DIAS COM PRECIP. PLUV, MENSAL (AUT)(n̼mero)  \
# Data Medicao
# 2008                                                        8.0
# 2008                                                        9.0
# 2008                                                       13.0
# 2008                                                       12.0
# 2008                                                       10.0
# 2008                                                       17.0
# 2008                                                       14.0
# 2008                                                       13.0
# 2008                                                       10.0
# 2008                                                       17.0
# 2008                                                        8.0
# 2008                                                       10.0
#
#              PRECIPITACAO TOTAL, MENSAL (AUT)(mm)  \
# Data Medicao
# ...

# %%
# data = data.reset_index()

# %%
data.groupby(level=0, axis=1).sum()
# Out:
#               Altitude Codigo Estacao   Data Final Data Inicial  Latitude  \
# Data Medicao
# 2008            426.69           A853   2023-05-30   2008-01-01 -28.60344
# 2008            426.69           A853   2023-05-30   2008-01-01 -28.60344
# 2008            426.69           A853   2023-05-30   2008-01-01 -28.60344
# 2008            426.69           A853   2023-05-30   2008-01-01 -28.60344
# 2008            426.69           A853   2023-05-30   2008-01-01 -28.60344
# ...                ...            ...          ...          ...       ...
# 2023            103.10           A803   2023-05-30   2008-01-01 -29.72500
# 2023            103.10           A803   2023-05-30   2008-01-01 -29.72500
# 2023            103.10           A803   2023-05-30   2008-01-01 -29.72500
# 2023            103.10           A803   2023-05-30   2008-01-01 -29.72500
# 2023            103.10           A803   2023-05-30   2008-01-01 -29.72500
#
#               Longitude  \
# Data Medicao
# ...

# %%
# data = data.groupby(level=0, axis=1).sum()
data = data.groupby(level=0, axis=0).mean()
data
# Out:
# C:\Users\caval\AppData\Local\Temp\ipykernel_20804\4240268599.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data = data.groupby(level=0, axis=0).mean()
#               NUMERO DE DIAS COM PRECIP. PLUV, MENSAL (AUT)(n̼mero)  \
# Data Medicao
# 2008                                                  11.557641
# 2009                                                  13.219212
# 2010                                                  12.761446
# 2011                                                  12.799031
# 2012                                                  10.551471
# 2013                                                  12.984163
# 2014                                                  14.150235
# 2015                                                  14.483544
# ...

# %%
data = data.reset_index()
data
# Out:
#    Data Medicao  NUMERO DE DIAS COM PRECIP. PLUV, MENSAL (AUT)(n̼mero)  \
# 0          2008                                          11.557641
# 1          2009                                          13.219212
# 2          2010                                          12.761446
# 3          2011                                          12.799031
# 4          2012                                          10.551471
# 5          2013                                          12.984163
# 6          2014                                          14.150235
# 7          2015                                          14.483544
# 8          2016                                          12.404977
# 9          2017                                          12.979296
# 10         2018                                          13.078000
# 11         2019                                          12.401575
# 12         2020                                          10.537500
# ...

# %%
data = data.iloc[:, :2]
data.columns = ['year', 'precipitation']
data
# Out:
#     year  precipitation
# 0   2008      11.557641
# 1   2009      13.219212
# 2   2010      12.761446
# 3   2011      12.799031
# 4   2012      10.551471
# 5   2013      12.984163
# 6   2014      14.150235
# 7   2015      14.483544
# 8   2016      12.404977
# 9   2017      12.979296
# 10  2018      13.078000
# 11  2019      12.401575
# 12  2020      10.537500
# 13  2021      11.409800
# 14  2022      12.710417
# 15  2023      11.791469

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(data=data, x='year', y='precipitation')
# Out:
# <Axes: xlabel='year', ylabel='precipitation'>

# %%
# descartar 2023 - dados incompletos
data = data.iloc[:-1, :]
data
# Out:
#     year  precipitation
# 0   2008      11.557641
# 1   2009      13.219212
# 2   2010      12.761446
# 3   2011      12.799031
# 4   2012      10.551471
# 5   2013      12.984163
# 6   2014      14.150235
# 7   2015      14.483544
# 8   2016      12.404977
# 9   2017      12.979296
# 10  2018      13.078000
# 11  2019      12.401575
# 12  2020      10.537500
# 13  2021      11.409800
# 14  2022      12.710417

# %%
plt.figure(figsize=(20, 10))

sns.barplot(data=data, x='year', y='precipitation')
# Out:
# <Axes: xlabel='year', ylabel='precipitation'>

# %%
red_grapes = pd.read_csv(f'{FULL_PATH}\\content\\red_grapes.csv')
white_grapes = pd.read_csv(f'{FULL_PATH}\\content\\white_grapes.csv')

# %%
red_grapes.tail()
# Out:
#      Ano  Arinarnoa  Cabernet Sauvignon   Malbec   Merlot  Marselan  Nebbiolo  \
# 10  2016      17691             3877852   267885  3286035    205095      3117
# 11  2017      69757             7242258   740327  8309646    385945      5494
# 12  2018      44775             6004627   628780  6257492    384278      9236
# 13  2020      90860             5889427   493966  6010486    449156      8642
# 14  2021    2785609             1857999  8502206   494356    154348    254738
#
#     Pinot Noir  Sangiovese   Tannat  Tempranillo  Teroldego  Touriga Nacional
# 10     1279105       26601   985207       210551      34019             53552
# 11     3676000       89404  3668851       357637      87034            108245
# 12     3240209       63832  2940306       278456      77625            122015
# 13     3588106       85292  3571972       442330     106764            150166
# 14     6184345     3324793  2634802       968038     717757             38910

# %%
red_grapes = red_grapes.set_index('Ano')
white_grapes = white_grapes.set_index('Ano')

# %%
# descartando anos que nao temos dados de producao
data = data.iloc[:-1, :]
data
# Out:
#     year  precipitation
# 0   2008      11.557641
# 1   2009      13.219212
# 2   2010      12.761446
# 3   2011      12.799031
# 4   2012      10.551471
# 5   2013      12.984163
# 6   2014      14.150235
# 7   2015      14.483544
# 8   2016      12.404977
# 9   2017      12.979296
# 10  2018      13.078000
# 11  2019      12.401575
# 12  2020      10.537500
# 13  2021      11.409800

# %%
ax1 = sns.set_style(style=None, rc=None )

fig, ax1 = plt.subplots(figsize=(12,6))

sns.barplot(data=data, x='year', y='precipitation', alpha=0.5, ax=ax1)

ax2 = ax1.twinx()

sns.lineplot(data=red_grapes.T, marker='o', sort = False, ax=ax2, dashes=False)
# Out:
# <Axes: >

# %%
ax1 = sns.set_style(style=None, rc=None )

fig, ax1 = plt.subplots(figsize=(12,6))

sns.barplot(data=data, x='year', y='precipitation', alpha=0.5, ax=ax1)

ax2 = ax1.twinx()

sns.lineplot(data=red_grapes, marker='o', sort = False, ax=ax2, dashes=False)
# Out:
# <Axes: xlabel='Ano'>

# %%
ax1 = sns.set_style(style=None, rc=None )

fig, ax1 = plt.subplots(figsize=(12,6))

sns.barplot(data=data, x='year', y='precipitation', alpha=0.5, ax=ax1)

ax2 = ax1.twinx()

sns.lineplot(data=white_grapes.T, marker='o', ax=ax2, dashes=False)
# Out:
# <Axes: >

# %%
white_grapes.T
# Out:
# Ano                2006     2007     2008     2009     2010     2011     2012  \
# Chardonnay      1830171  1752488  5829449  4812743  3836555  4916344  6347044
# Gewurztraminer   142266   284818   196483   155338   105186   206833   327678
# Viognier          16581    37628    41338    49935    76145   144979   200288
#
# Ano                2013     2014     2015     2016     2017     2018     2020  \
# Chardonnay      6174156  5821514  7253167  3070142  7856910  6068902  6514864
# Gewurztraminer   239469   162083   207303    85385   223350   208171   192058
# Viognier         247081   149333   285217    95231   365103   470555   531026
#
# Ano                2021
# Chardonnay      4200465
# Gewurztraminer  3201453
# Viognier          78305

# %%
data
# Out:
#     year  precipitation
# 0   2008      11.557641
# 1   2009      13.219212
# 2   2010      12.761446
# 3   2011      12.799031
# 4   2012      10.551471
# 5   2013      12.984163
# 6   2014      14.150235
# 7   2015      14.483544
# 8   2016      12.404977
# 9   2017      12.979296
# 10  2018      13.078000
# 11  2019      12.401575
# 12  2020      10.537500
# 13  2021      11.409800

# %%
red_grapes = red_grapes.reset_index()

# %%
ax1 = sns.set_style(style=None, rc=None )

fig, ax1 = plt.subplots(figsize=(12,6))

sns.barplot(data=data, x='year', y='precipitation', alpha=0.5, ax=ax1)

ax2 = ax1.twinx()

sns.lineplot(data=red_grapes, marker='o', sort = False, ax=ax2, dashes=False)
# Out:
# <Axes: >

# %%
red_grapes.T.iloc[1:, :]
# Out:
#                           0         1         2         3        4         5   \
# Arinarnoa              11480     24878     12686     39607    35790     49376
# Cabernet Sauvignon  12063009  14489153  16646632  13229864  6617553  13039126
# Malbec                148733    399928    414138    393256   318059    636608
# Merlot               8449561  11399362  11866618   8876279  6179006  12510489
# Marselan               66815    109574    181823    228360   200025    339023
# Nebbiolo               11082     13971     10019     14148    11986     21342
# Pinot Noir           1161465   1270351   1930823   1387200  1309849   2513274
# Sangiovese            133402    115475    405224    303438   258484    359833
# Tannat               3055931   3514880   4711255   4199190  2266985   4152135
# Tempranillo           111158    192063    241017    242484    63526    256836
# Teroldego              51645     61659     69876    105372    68593    179095
# ...

# %%
white_grapes = white_grapes.reset_index()

# %%
white_grapes
# Out:
#      Ano  Chardonnay  Gewurztraminer  Viognier
# 0   2006     1830171          142266     16581
# 1   2007     1752488          284818     37628
# 2   2008     5829449          196483     41338
# 3   2009     4812743          155338     49935
# 4   2010     3836555          105186     76145
# 5   2011     4916344          206833    144979
# 6   2012     6347044          327678    200288
# 7   2013     6174156          239469    247081
# 8   2014     5821514          162083    149333
# 9   2015     7253167          207303    285217
# 10  2016     3070142           85385     95231
# 11  2017     7856910          223350    365103
# 12  2018     6068902          208171    470555
# 13  2020     6514864          192058    531026
# 14  2021     4200465         3201453     78305

# %%
ax1 = sns.set_style(style=None, rc=None )

fig, ax1 = plt.subplots(figsize=(12,6))

sns.barplot(data=data, x='year', y='precipitation', alpha=0.5, ax=ax1)

ax2 = ax1.twinx()

sns.lineplot(data=white_grapes, marker='o', sort = False, ax=ax2, dashes=False)
# Out:
# <Axes: >

# %%
#https://www.guiadecaxiasdosul.com/passeios/uvas-de-mesa/circuito-das-uvas-de-mesa-44
